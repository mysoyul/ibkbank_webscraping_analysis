# %% [markdown]
# ### Melon 100 챠트 스크래핑
# * 100곡 노래의 제목,ID를 추출
# * Song ID를 상세 페이지를 100번 요청을 해서 상세정보를 추출
# * 100곡의 노래상세정보를 Json file에 저장한다
# * Json file에 정보를 읽어서 Pandas의 DataFrame에 저장해서 표 데이터를 만들기
# * 표 데이터를 Maria DB에 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.melon.com/chart/index.htm'
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

# 요청을 보내기
res = requests.get(url, headers=req_header)
print(type(res))
# Out:
# <class 'requests.models.Response'>

# %%
# 응답코드 200(ok) 가 정상이면
if res.ok:
    #response 객체에 포함된 text를 추출
    html = res.text
    #BeautifulSoup 객체의 역할 - html 문서 파싱
    #텍스트를 추출(parsing)하기 위해서 응답 text와 parser 이름을 전달한다.
    soup = BeautifulSoup(html, 'html.parser')
    
    #<div id='tb_list'> div 태그 선택
    print(len(soup.select('div#tb_list'))) #1
    #<div id='tb_list'> 하위에 있는 tr 태그 선택
    print(len(soup.select('div#tb_list tr'))) #101
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'>
    print(len(soup.select('div#tb_list tr div.wrap_song_info'))) #200
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 하위에 a 태그 
    print(len(soup.select('div#tb_list tr div.wrap_song_info a'))) #423
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 하위에 a 태그 
    #a 태그의 href 속성값에 playSong이라는 문자열 포함된 a 태그를 선택 #100
    print(len(soup.select('div#tb_list tr div.wrap_song_info a[href*="playSong"]')))
    
    atag_list = soup.select('div#tb_list tr div.wrap_song_info a[href*="playSong"]')
    song_list = []
    
    for idx,atag in enumerate(atag_list,1):
        song_dict = {}
        title = atag.text   #<a>노래제목</a>  a tag의 text를 추출
        href = atag['href'] #<a href="playSong">   href속성의 값을 추출
        matched = re.search(r'(\d+)\);', href)  # 정규표현식 패턴으로 숫자를 검색
        song_id = matched.group(1) # 정규표현식 결과값을 가져오기
        #song 상세페이지 url를 조립
        detail_link = f'https://www.melon.com/song/detail.htm?songId={song_id}'
        #song 의 제목과 상세페이지url를 dict에 저장
        song_dict['title'] = title
        song_dict['song_id'] = song_id
        song_dict['link'] = detail_link
        #각각의 song 정보를 저장한 dict를 list에 저장
        song_list.append(song_dict)
else:
    print('Error 코드 ', res.status_code)

print(len(song_list))
song_list[0:3]
# Out:
# 1
# 101
# 200
# 491
# 100
# 100
# [{'title': '회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)',
#   'song_id': '34256568',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34256568'},
#  {'title': '쉬어 (Feat. MINO) (Prod. GRAY)',
#   'song_id': '34215822',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34215822'},
#  {'title': 'Wake Up (Prod. 코드 쿤스트)',
#   'song_id': '34215821',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34215821'}]

# %% [markdown]
# #### Song ID를 상세 페이지를 100번 요청을 해서 상세정보를 추출

# %%
song_list[71:]
# Out:
# [{'title': '나의 첫사랑',
#   'song_id': '34097306',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34097306'},
#  {'title': 'METEOR',
#   'song_id': '32224272',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32224272'},
#  {'title': '소용돌이',
#   'song_id': '34140615',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34140615'},
#  {'title': 'Life Goes On',
#   'song_id': '33077234',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33077234'},
#  {'title': '그날에 나는 맘이 편했을까',
#   'song_id': '33107649',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33107649'},
#  {'title': '잠이 오질 않네요',
#   'song_id': '33013877',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33013877'},
#  {'title': '오래된 노래',
#   'song_id': '3894276',
#   'link': 'https://www.melon.com/song/detail.htm?songId=3894276'},
#  {'title': 'Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afrojack)',
#   'song_id': '5473462',
#   'link': 'https://www.melon.com/song/detail.htm?songId=5473462'},
#  {'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   'song_id': '32003395',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32003395'},
#  {'title': '아로하',
#   'song_id': '32491274',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32491274'},
#  {'title': 'XOXO',
#   'song_id': '34187867',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34187867'},
#  {'title': 'Timeless',
#   'song_id': '1944399',
#   'link': 'https://www.melon.com/song/detail.htm?songId=1944399'},
#  {'title': 'Crush',
#   'song_id': '34140617',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34140617'},
#  {'title': '2002',
#   'song_id': '31029291',
#   'link': 'https://www.melon.com/song/detail.htm?songId=31029291'},
#  {'title': '어푸 (Ah puh)',
#   'song_id': '33372788',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33372788'},
#  {'title': '낮 밤 (feat. 박재범)',
#   'song_id': '34186697',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34186697'},
#  {'title': '그리워 그리워',
#   'song_id': '34154224',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34154224'},
#  {'title': '운전만해 (We Ride)',
#   'song_id': '32860397',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32860397'},
#  {'title': '매일 그대라서 행복하다',
#   'song_id': '34140619',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34140619'},
#  {'title': '밤하늘의 별을(Original)',
#   'song_id': '34194115',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34194115'},
#  {'title': '가까이 있어서 몰랐어',
#   'song_id': '34190821',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34190821'},
#  {'title': '안녕 (Hello)',
#   'song_id': '33527705',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33527705'},
#  {'title': 'Sticker',
#   'song_id': '33901877',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33901877'},
#  {'title': '그리워하는 것까지',
#   'song_id': '34140620',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34140620'},
#  {'title': '사랑은 언제나 목마르다 (N번째 연애 X 이해리 (다비치))',
#   'song_id': '34018319',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34018319'},
#  {'title': 'PANG!',
#   'song_id': '34140618',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34140618'},
#  {'title': '2 MINUS 1 (Digital Only)',
#   'song_id': '34140621',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34140621'},
#  {'title': 'Ready to love',
#   'song_id': '33594897',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33594897'},
#  {'title': '치맛바람 (Chi Mat Ba Ram)',
#   'song_id': '33589260',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33589260'}]

# %%
import requests
from bs4 import BeautifulSoup
import re

req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

song_detail_list = []
for idx,song in enumerate(song_list,1):
    song_detail_dict = {}
    song_url = song['link']
    res = requests.get(song_url, headers=req_header)
    print(idx, song['title'])
    if res.ok:
        html = res.text
        soup = BeautifulSoup(html,'html.parser')
        #노래제목
        song_detail_dict['곡명'] = song['title']
        #가수
        song_detail_dict['가수'] = soup.select('a[href*="goArtistDetail"] span')[0].text
        #앨범
        song_detail_dict['앨범'] = soup.select('div.meta dd')[0].text
        #발매일
        song_detail_dict['발매일'] = soup.select('div.meta dd')[1].text
        #장르
        song_detail_dict['장르'] = soup.select('div.meta dd')[2].text   
        
        #좋아요건수
        song_id = song['song_id']
        like_url = f'https://www.melon.com/commonlike/getSongLike.json?contsIds={song_id}'
        like_res = requests.get(like_url,headers=req_header)
        like_cnt = like_res.json()['contsLike'][0]['SUMMCNT']
        song_detail_dict['좋아요'] = like_cnt
        
        #가사
        if soup.select('div#d_video_summary'):
            lyric = soup.select('div#d_video_summary')[0].text
        else:
            lyric = ''
        regexp = re.compile(r'[\n\r\t]')        
        song_detail_dict['가사'] = regexp.sub('',lyric.strip())
        #각각의 Song정보를 담고 있는 dict를 list에 저장
        song_detail_list.append(song_detail_dict)

print(len(song_detail_list))
print(song_detail_list[0:2])
# Out:
# 1 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 2 쉬어 (Feat. MINO) (Prod. GRAY)
# 3 Wake Up (Prod. 코드 쿤스트)
# 4 strawberry moon
# 5 사랑은 늘 도망가
# 6 Savage
# 7 STAY
# 8 신호등
# 9 다정히 내 이름을 부르면
# 10 TROUBLE (Prod. Slom)
# 11 Next Level
# 12 너와 나의 Memories
# 13 My Universe
# 14 이제 나만 믿어요
# 15 너를 생각해
# 16 OHAYO MY NIGHT
# 17 Permission to Dance
# 18 낙하 (with 아이유)
# 19 Butter
# 20 바라만 본다
# 21 그대라는 사치
# 22 별빛 같은 나의 사랑아
# 23 다시 사랑한다면 (김필 Ver.)
# 24 Weekend
# 25 Dynamite
# 26 Peaches (Feat. Daniel Caesar & Giveon)
# 27 HERO
# 28 잊었니
# 29 Bad Habits
# 30 끝사랑
# 31 헤픈 우연
# 32 가시 (Prod. 코드 쿤스트)
# 33 Bk Love
# 34 고백
# 35 라일락
# 36 Celebrity
# 37 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 38 찰나가 영원이 될 때 (The Eternal Moment)
# 39 문득
# 40 좋아좋아
# 41 Rock with you
# 42 DUMB DUMB
# 43 밤하늘의 별을(2020)
# 44 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 45 Queendom
# 46 롤린 (Rollin')
# 47 내 손을 잡아
# 48 계단말고 엘리베이터
# 49 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 50 나 그댈위해 시 한편을 쓰겠어
# 51 Dun Dun Dance
# 52 Savage Love (Laxed - Siren Beat) (BTS Remix)
# 53 비가 오는 날엔 (2021)
# 54 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 55 Off My Face
# 56 봄날
# 57 모든 날, 모든 순간 (Every day, Every Moment)
# 58 밝게 빛나는 별이 되어 비춰줄게
# 59 추억은 만남보다 이별에 남아
# 60 XOXO
# 61 비와 당신
# 62 Blueming
# 63 ASAP
# 64 취기를 빌려 (취향저격 그녀 X 산들)
# 65 가을 우체국 앞에서
# 66 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 67 Life Goes On
# 68 가을 타나 봐
# 69 하루만 더
# 70 Lovesick Girls
# 71 어제 너는 나를 버렸어
# 72 에잇(Prod.&Feat. SUGA of BTS)
# 73 멜로디
# 74 그날에 나는 맘이 편했을까
# 75 여전히 아름다운지
# 76 SCIENTIST
# 77 너는 내 세상이었어
# 78 색안경 (STEREOTYPE)
# 79 METEOR
# 80 LOCO
# 81 별거 없던 그 하루로
# 82 잠이 오질 않네요
# 83 아로하
# 84 오래된 노래
# 85 그리워 그리워
# 86 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 87 Cold Blooded
# 88 Timeless
# 89 2002
# 90 가까이 있어서 몰랐어
# 91 Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afrojack)
# 92 다음생이 있다면 당신을 만나서 다시 사랑할래요
# 93 밤하늘의 별을(Original)
# 94 나비효과
# 95 나의 첫사랑
# 96 Favorite (Vampire)
# 97 어푸 (Ah puh)
# 98 손을 잡아줘요
# 99 운전만해 (We Ride)
# 100 안녕 (Hello)
# 100
# [{'곡명': '회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)', '가수': 'sokodomo', '앨범': '쇼미더머니 10 Episode 2', '발매일': '2021.11.13', '장르': '랩/힙합', '좋아요': 56353, '가사': "내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린 매일 달려가언제쯤 끝나 난 잘 몰라어머, 벌써 정신없이 달려왔어Speed up 어제로 돌아가는 시곌 보다가어려워 어른이 되어가는 과정이 Uh huhOn the road, 24 시간이 아까워 Uh huhBig noise, Everything brand new어렸을 때처럼 바뀌지 않는 걸찾아 나섰단 말야 왜냐면 그때가 더 좋았어 난So let me go back타임머신 타고 I'll go back승호가 좋았을 때처럼만내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우리인생은 회전목마우린 매일 달려가언제쯤 끝나 난 잘 몰라빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마어머 벌써 정신없이 달려왔어Speed up 어제로 돌아가는 시곌 보다가청춘까지 뺏은 현재 탓할 곳은 어디 없네Twenty two 세에게 너무 큰 벽그게 말로 하고 싶어도 어려웠어가끔은 어렸을 때로 돌아가불가능하단 건 나도 잘 알아그 순간만 고칠 수 있다면지금의 나는 더 나았을까달려가는 미터기 돈은 올라가기사님과 어색하게 눈이 맞아창문을 열어보지만 기분은 좋아지지 않아그래서 손을 밖으로 쭉 뻗어 쭉 뻗어흔들리는 택시는 어느새 목적지에 도달했다고 해방 하나 있는 내 집 안의 손에 있던 짐들은 내가 힘들 때마다이 노래가 찾아와세상이 둥근 것처럼 우리인생은 회전목마우린 계속 달려가언제쯤 끝날지 잘 몰라빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마I'm on a TV showYou would never even know사실 얼마나 많이불안했는지정신없이 돌아서 어딜 봐야 할지 모르겠어들리나요 여길 보란 말이빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마"}, {'곡명': '쉬어 (Feat. MINO) (Prod. GRAY)', '가수': '아넌딜라이트(Anandelight)', '앨범': '쇼미더머니 10 Episode 1', '발매일': '2021.11.06', '장르': '랩/힙합', '좋아요': 63307, '가사': '오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아꿈꾸러 가자 좀 쉬어 쉬어집 앞 공사판 숨을 쉬어밤이 되면 맘의 눈을 떠관중들이 내는 환호성보이지 않지만 꿈을 꿨어 yeah어린 나는 이제 춤을 춰2014의 불확실함에벌벌 떨던 꼬마에게 말을 거네 yeah"숨을 쉬어"숨을 들이쉬고 내쉬고를 반복다시 넘어지더라도 일어나길 반복결국 끝에 가선 푸른 풀밭이 날 반겨쉴 만한 물가에서 비파와 수금으로 반격 yeah이제 그냥 켜 봐라 TV마술사 아닌데 NOW YOU SEE ME거기서 외칠 말은 단 하나다른 거 없다 마, 다만 하나님의 사랑그저 편히 쉬어 너와 나의 mood소리 높여서 숨을 내쉬어Just one more time한 번 더 준비 I\'m ready숨을 크게 들이쉬고 나서Let it burn Let it burnI\'mma show you how I did itY\'all get it?난 못 쉬어서 한숨 쉬어한숨 쉬어 가려 나온 게 show많은 게 쉬워져 버려 아쉬워대체 우리 언제 시원한 공기 마셔1 for the show 2 for the money not her8 mile 속의 에미넴이 말했어기회는 한번 쥐어진 microphoneYo 첫 마디에 D.O.G we on it나 서울로 다시 올라왔어 그때 그 건방진 녀석언제 이리 컸어 관심 없어서 잘 몰랐어So who that unofficialboyy 봤어이수린 that\'s my name wassupWassup 나왔어 방송 why 돈 벌러 왔어다시 돌아왔어 돌고 돌고 돌아서다시 돌아왔어 돌고 돌고 돌아그물, 덫, 발사대기, 포획하러 showShow me the money, ackermann또다시 돌아왔어 벌게 내비 둬 그냥 sure오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아꿈꾸러 가자 좀 쉬어 쉬어2000 slash필요 없어 나만이 내 빽그때 지하방의 제 목소리의 값어친좀 있음 곧 돈이 됩니다 아버지Ha 물음표사람들은 이제 와서 내게 물어 또그냥 아버지의 코골이가 구슬퍼숨통 틔워주려 수천수만 번 죽였던나의 스무 살에 하는 CPRClick, Pow, Revival 숨 쉬어두 번째 삶의 첫 타이틀곡은아이러니하게 "쉬어"비워 나를 이제 미워하긴 너무나도 싫어Yeah I believeYeah now, so I believe내가 너도 깨워줄게너가 모르게 쓰러진 너를 위해Clap 숨 쉬어, 숨 쉬어yeah 내일의 내 일은 내일의 내가 데이게 해채이고 베이던, 베이고 패이든 재생패배의 냄새는 매캐해 매연의 백배야 baby밝았던 눈, 밝았던 move, 가졌던 그시절의 You 불러 일루 와이제 그 쓰레기들을 다 모아놓고 피우던 담배를 그 위에 투하쉬는 것도 일, 일은 걍 일잠드는 것도 내겐 다 일눈 뜨고 있기 피곤하지숨만 쉬어도 돈이 들어가니그 돈을 위해 난 지금도 못 쉬어커피가 내 포션 음음내 무한도전종방연은 멀었지15년째 꾸준하게 넘고 있는 이 허들은 여전히 견고하지만까진 무릎에도 내 비전은 새롭게 내 빽은 1만 시간동기들은 내게 말해 쟤는 출퇴근 안 해 나보다 자유롭지넌 몰라 그 자유로움의 무게가 얼마인지내 가벼운 톤에 걸맞지 않는 내 책임감 장남의 고뇌내 팀 내 동생 내 친구 내 식구를 담아놨기에 내 목은이제 안 쉬어 쉬어 크게 숨을 쉬어 이미 난 Man of the year음 Cheers Cheers 저 하늘 위로 렉시 누나처럼 다 일어서 yeah오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아꿈꾸러 가자 좀 쉬어 쉬어Pop like Beatles 시대의 시를 노래하지내 전생은 이름 모르는 꽃일 거야향기를 뿌리지리스너들의 암술을 찾아내고 넌 꽂힐 거야쉬어가지 말란 뭣 같은 말에 혹 하지 마다 똑같이 말해 또 거짓말 뻔하지콩깍질 껴야만 논하지 평판난 결관 몰라 평가해 과정만쉬어 같이 all night long빨랑 빨랑 모여봐 여기 폴라로이드찰칵 찰칵 거리지 모두 명장면살짝 살짝 설렜어 like an OH MY GIRL쉬어, 직역하면 심호흡거북이는 비웃어 쉼표의 미덕개미들의 피로와 베짱이의 빈곤을비교하자면 난 기타를 집어우린 환상이라면 MBTI가 닿지 않는 곳 그 이상을 봐나는 기다리지당신의 애인과 다신 안 올 긴 Field trip천천히 해 모두가 급해우린 꿈들 그 언저리에서도전해보며 생을 보내자고왜 모델이 런웨이를 겁내는 건데건배오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아꿈꾸러 가자 좀 쉬어 쉬어쉼표, 찍게 해 줘이름표와 나의 ego그 사이에 많은 허들넘어 다니기엔 지쳐오늘은 눈 붙여조금만 쉬어숨을 들이 마셔조금만 쉬어'}]

# %% [markdown]
# #### Song 정보를 담고 있는 List를 JSON file로 저장

# %%
import json

#json file 생성
with open('data/songs.json','w', encoding='utf8') as file:
    json.dump(song_detail_list, file)

# %% [markdown]
# #### Json File 읽기

# %%
import json

with open('data/songs.json','r',encoding='utf8') as file:
    contents = file.read()
    song_json = json.loads(contents)
    
print(len(song_json))
print(type(song_json))
# Out:
# 100
# <class 'list'>

# %% [markdown]
# #### Json file을 읽어서 Pandas의 DataFrame 객체에 저장

# %%
import pandas as pd

song_df2 = pd.read_json('data/songs.json')
song_df2.head()
# Out:
#                                        곡명                   가수  \
# 0  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)             sokodomo
# 1            쉬어 (Feat. MINO) (Prod. GRAY)  아넌딜라이트(Anandelight)
# 2                  Wake Up (Prod. 코드 쿤스트)                   개코
# 3                         strawberry moon                  아이유
# 4                               사랑은 늘 도망가                  임영웅
#
#                    앨범         발매일          장르     좋아요  \
# 0  쇼미더머니 10 Episode 2  2021.11.13        랩/힙합   56353
# 1  쇼미더머니 10 Episode 1  2021.11.06        랩/힙합   63307
# 2  쇼미더머니 10 Episode 1  2021.11.06        랩/힙합   48497
# 3     strawberry moon  2021.10.19        록/메탈  153377
# 4  신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마   71390
#
#                                                   가사
# 0  내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린...
# 1  오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아...
# 2  "무거운 몸을 또 일으켜 세워난 부서지는 게 무섭지 않아힘들 땐 잠시만 갓길에 세워...
# 3  달이 익어가니 서둘러 젊은 피야민들레 한 송이 들고사랑이 어지러이 떠다니는 밤이야날...
# 4  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...

# %%
song_df2.tail()
# Out:
#                                    곡명         가수  \
# 95  사랑은 언제나 목마르다 (N번째 연애 X 이해리 (다비치))  이해리 (다비치)
# 96                              PANG!        세븐틴
# 97           2 MINUS 1 (Digital Only)        세븐틴
# 98                      Ready to love        세븐틴
# 99              치맛바람 (Chi Mat Ba Ram)     브레이브걸스
#
#                                         앨범         발매일    장르    좋아요  \
# 95       사랑은 언제나 목마르다 (N번째 연애 X 이해리 (다비치))  2021.09.29   발라드  13369
# 96      SEVENTEEN 9th Mini Album 'Attacca'  2021.10.22  랩/힙합  38759
# 97      SEVENTEEN 9th Mini Album 'Attacca'  2021.10.22  록/메탈  39254
# 98  SEVENTEEN 8th Mini Album 'Your Choice'  2021.06.18    댄스  77781
# 99                            Summer Queen  2021.06.17    댄스  93850
#
#                                                    가사
# 95  그렇게 많이 사랑한다 했는데이제야 사랑을 알 것 같아요부탁이 있어 제발 용서 마세요...
# 96  지구의 온도가 올라간다 해서내가 터질 일은 없을 거예요온도계는 파란색을 입어도내 맘...
# 97  What’s two minus one?Hope you listen to this s...
# 98  I’m ready to love내게 말해 줘 Can we stay togetherI...
# 99  You know what it isB. girls are back, Brave So...

# %%
import pandas as pd

#DataFrame 객체 생성
song_df = pd.DataFrame(columns=['곡명','가수','앨범','발매일','장르','좋아요','가사'])
#song_df

for song in song_detail_list:
    #song(dict 타입) <=> Series 객체
    series_obj = pd.Series(song)
    #Series 객체를 DataFrame에 append 하기
    song_df = song_df.append(series_obj, ignore_index=True)

song_df.head(3)
# Out:
#                                        곡명                   가수  \
# 0  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)             sokodomo
# 1            쉬어 (Feat. MINO) (Prod. GRAY)  아넌딜라이트(Anandelight)
# 2                  Wake Up (Prod. 코드 쿤스트)                   개코
#
#                    앨범         발매일    장르    좋아요  \
# 0  쇼미더머니 10 Episode 2  2021.11.13  랩/힙합  56353
# 1  쇼미더머니 10 Episode 1  2021.11.06  랩/힙합  63307
# 2  쇼미더머니 10 Episode 1  2021.11.06  랩/힙합  48497
#
#                                                   가사
# 0  내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린...
# 1  오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아...
# 2  "무거운 몸을 또 일으켜 세워난 부서지는 게 무섭지 않아힘들 땐 잠시만 갓길에 세워...

# %%
song_df.tail(3)
# Out:
#                 곡명        가수                          앨범         발매일  \
# 97         손을 잡아줘요       이하이    지금, 헤어지는 중입니다 OST Part.2  2021.11.14
# 98  운전만해 (We Ride)    브레이브걸스                     We Ride  2020.08.14
# 99      안녕 (Hello)  조이 (JOY)  안녕 (Hello) - Special Album  2021.05.31
#
#             장르     좋아요                                                 가사
# 97  발라드, 국내드라마    5115  내 맘을 깊이 들여다보면작은 구멍이 하나 있어요아무도 모르게 나조차도 모르게자라나고...
# 98          댄스  131125  넌 운전만 해계속 운전만 해왜 이리 된 걸까 우리 사이가갑자기 어색해졌단 걸왜 달라...
# 99        록/메탈  114644  외로운 날들이여 모두 다 안녕내 마음속의 눈물들도 이제는 안녕 Oh어제의 너는 바람...

# %%
song_df.sample(5)
# Out:
#                                         곡명          가수  \
# 86                            Cold Blooded  제시 (Jessi)
# 60                                   비와 당신         이무진
# 0   회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)    sokodomo
# 61                                Blueming         아이유
# 92                       밤하늘의 별을(Original)         임한별
#
#                           앨범         발매일           장르     좋아요  \
# 86              Cold Blooded  2021.10.12         랩/힙합   21849
# 60  슬기로운 의사생활 시즌2 OST Part 1  2021.06.18  록/메탈, 국내드라마   93359
# 0         쇼미더머니 10 Episode 2  2021.11.13         랩/힙합   56353
# 61                 Love poem  2019.11.18         록/메탈  323012
# 92         밤하늘의 별을(Original)  2021.11.02          발라드   12235
#
#                                                    가사
# 86  I’m so cold blooded I’m so naughty 우린 전문가 넌 돌팔...
# 60  이젠 당신이 그립지 않죠보고 싶은 마음도 없죠사랑한 것도 잊혀 가네요조용하게알 수 ...
# 0   내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린...
# 61  ‘뭐해?‘라는 두 글자에‘네가 보고 싶어’ 나의 속마음을 담아 우이모티콘 하나하나 ...
# 92  너의 집 앞에서 한참 동안 기다린 거야네가 오는 길에 혹시나 마주칠까 봐널 만나게 ...

# %%
print('shape ', song_df.shape)
print('colums ', song_df.columns)
print('index ', song_df.index)
print('values ', song_df.values[0:1]) #2차원 배열
# Out:
# shape  (100, 7)
# colums  Index(['곡명', '가수', '앨범', '발매일', '장르', '좋아요', '가사'], dtype='object')
# index  RangeIndex(start=0, stop=100, step=1)
# values  [['회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)' 'sokodomo'
#   '쇼미더머니 10 Episode 2' '2021.11.13' '랩/힙합' 56353
#   "내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린 매일 달려가언제쯤 끝나 난 잘 몰라어머, 벌써 정신없이 달려왔어Speed up 어제로 돌아가는 시곌 보다가어려워 어른이 되어가는 과정이 Uh huhOn the road, 24 시간이 아까워 Uh huhBig noise, Everything brand new어렸을 때처럼 바뀌지 않는 걸찾아 나섰단 말야 왜냐면 그때가 더 좋았어 난So let me go back타임머신 타고 I'll go back승호가 좋았을 때처럼만내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우리인생은 회전목마우린 매일 달려가언제쯤 끝나 난 잘 몰라빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마어머 벌써 정신없이 달려왔어Speed up 어제로 돌아가는 시곌 보다가청춘까지 뺏은 현재 탓할 곳은 어디 없네Twenty two 세에게 너무 큰 벽그게 말로 하고 싶어도 어려웠어가끔은 어렸을 때로 돌아가불가능하단 건 나도 잘 알아그 순간만 고칠 수 있다면지금의 나는 더 나았을까달려가는 미터기 돈은 올라가기사님과 어색하게 눈이 맞아창문을 열어보지만 기분은 좋아지지 않아그래서 손을 밖으로 쭉 뻗어 쭉 뻗어흔들리는 택시는 어느새 목적지에 도달했다고 해방 하나 있는 내 집 안의 손에 있던 짐들은 내가 힘들 때마다이 노래가 찾아와세상이 둥근 것처럼 우리인생은 회전목마우린 계속 달려가언제쯤 끝날지 잘 몰라빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마I'm on a TV showYou would never even know사실 얼마나 많이불안했는지정신없이 돌아서 어딜 봐야 할지 모르겠어들리나요 여길 보란 말이빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마빙빙 돌아가는 회전목마처럼영원히 계속될 것처럼빙빙 돌아올 우리의 시간처럼인생은 회전목마"]]

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   곡명      100 non-null    object
#  1   가수      100 non-null    object
#  2   앨범      100 non-null    object
#  3   발매일     100 non-null    object
#  4   장르      100 non-null    object
#  5   좋아요     100 non-null    object
#  6   가사      100 non-null    object
# dtypes: object(7)
# memory usage: 5.6+ KB

# %%
#가수 컬럼의 값을 선택
song_df['가수']
# Out:
# 0                sokodomo
# 1     아넌딜라이트(Anandelight)
# 2                      개코
# 3                     아이유
# 4                     임영웅
#              ...
# 95                NCT 127
# 96                    아이유
# 97                    이하이
# 98                 브레이브걸스
# 99               조이 (JOY)
# Name: 가수, Length: 100, dtype: object

# %%
#가수별로 row counting
song_df['가수'].value_counts()
# Out:
# 임영웅                  10
# 아이유                   7
# 방탄소년단                 6
# 이무진                   3
# 볼빨간사춘기                2
#                      ..
# 10CM                  1
# 케이윌                   1
# Ed Sheeran            1
# 스탠딩 에그                1
# Red Velvet (레드벨벳)     1
# Name: 가수, Length: 65, dtype: int64

# %%
#장르별 row counting
song_df['장르'].value_counts()
# Out:
# 댄스                21
# 발라드               19
# 랩/힙합              15
# 발라드, 국내드라마         9
# 성인가요               7
# POP                7
# 록/메탈               7
# R&B/Soul, 인디음악     3
# R&B/Soul           3
# 발라드, 인디음악          3
# 록/메탈, 국내드라마        2
# 포크/블루스             1
# 인디음악, 포크/블루스       1
# 일렉트로니카             1
# 인디음악, 록/메탈         1
# Name: 장르, dtype: int64

# %%
#unique 한 장르명 가져오기
song_df['장르'].unique()
# Out:
# array(['랩/힙합', '록/메탈', '발라드, 국내드라마', '댄스', 'POP', '발라드', '성인가요',
#        'R&B/Soul, 인디음악', 'R&B/Soul', '발라드, 인디음악', '록/메탈, 국내드라마', '포크/블루스',
#        '인디음악, 포크/블루스', '일렉트로니카', '인디음악, 록/메탈'], dtype=object)

# %%
#가사 empty string check
song_df.loc[song_df['가사'] == '']
# Out:
#                                                    곡명            가수      앨범  \
# 90  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...  David Guetta  Listen
#
#            발매일      장르    좋아요 가사
# 90  2014.11.25  일렉트로니카  53820

# %%
#방탄소년단 의 노래를 모두 선택
song_df['가수'] == '방탄소년단'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: 가수, Length: 100, dtype: bool

# %% [markdown]
# ### 특정행이나 열을 선택
# * loc[]  과 iloc[] 사용
# * 1) Slicing 을 사용해서 구간을 선택 행과열을 선택  :
# * 2) 특정행과 특정열을 선택 [ ]
# * 3) 조건식을 만족하는 행을 선택

# %%
#loc[]  - location의 약자
#특정행이나 특정열을 선택할 때 사용한다. 
#loc[행을 선택 기준 ,  열을 선택 기준 ]

#인덱스가 0 부터 5까지의 행과 모든열을 선택
song_df.loc[0:5,:]
# Out:
#                                        곡명                   가수  \
# 0  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)             sokodomo
# 1            쉬어 (Feat. MINO) (Prod. GRAY)  아넌딜라이트(Anandelight)
# 2                  Wake Up (Prod. 코드 쿤스트)                   개코
# 3                         strawberry moon                  아이유
# 4                               사랑은 늘 도망가                  임영웅
# 5                                  Savage                aespa
#
#                             앨범         발매일          장르     좋아요  \
# 0           쇼미더머니 10 Episode 2  2021.11.13        랩/힙합   56353
# 1           쇼미더머니 10 Episode 1  2021.11.06        랩/힙합   63307
# 2           쇼미더머니 10 Episode 1  2021.11.06        랩/힙합   48497
# 3              strawberry moon  2021.10.19        록/메탈  153377
# 4           신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마   71390
# 5  Savage - The 1st Mini Album  2021.10.05          댄스  117613
#
#                                                   가사
# 0  내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린...
# 1  오늘은 눈 좀 붙이고 쉬어굳어진 몸을 풀어차가운 목걸이가 조여숨이 잘 안 쉬어지잖아...
# 2  "무거운 몸을 또 일으켜 세워난 부서지는 게 무섭지 않아힘들 땐 잠시만 갓길에 세워...
# 3  달이 익어가니 서둘러 젊은 피야민들레 한 송이 들고사랑이 어지러이 떠다니는 밤이야날...
# 4  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 5  Oh my gosh!Don't you know I’m a Savage?I’m a K...

# %%
#Slicing으로 인덱스가 0부터 8까지 , 1줄 씩 skip
song_df.loc[0:8:2,:]
# Out:
#                                        곡명             가수  \
# 0  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)       sokodomo
# 2                  Wake Up (Prod. 코드 쿤스트)             개코
# 4                               사랑은 늘 도망가            임영웅
# 6                                    STAY  The Kid LAROI
# 8                           다정히 내 이름을 부르면           경서예지
#
#                            앨범         발매일          장르     좋아요  \
# 0          쇼미더머니 10 Episode 2  2021.11.13        랩/힙합   56353
# 2          쇼미더머니 10 Episode 1  2021.11.06        랩/힙합   48497
# 4          신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마   71390
# 6                        Stay  2021.07.09         POP  185985
# 8  다정히 내 이름을 부르면 (경서예지 x 전건호)  2021.05.19         발라드   83093
#
#                                                   가사
# 0  내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린...
# 2  "무거운 몸을 또 일으켜 세워난 부서지는 게 무섭지 않아힘들 땐 잠시만 갓길에 세워...
# 4  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 6  I do the same thing I told youthat I never wou...
# 8  끝없이 별빛이 내리던 밤기분 좋은 바람이두 빰을 스치고새벽 바다 한곳을 보는아름다운...

# %%
#여러개의 특정 행과 모든열을 선택
song_df.loc[[0,3,7,8]]
#song_df.loc[[0,3,7,8],:]
# Out:
#                                        곡명        가수  \
# 0  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)  sokodomo
# 3                         strawberry moon       아이유
# 7                                     신호등       이무진
# 8                           다정히 내 이름을 부르면      경서예지
#
#                            앨범         발매일    장르     좋아요  \
# 0          쇼미더머니 10 Episode 2  2021.11.13  랩/힙합   56353
# 3             strawberry moon  2021.10.19  록/메탈  153377
# 7                         신호등  2021.05.14  록/메탈  239016
# 8  다정히 내 이름을 부르면 (경서예지 x 전건호)  2021.05.19   발라드   83093
#
#                                                   가사
# 0  내가 슬플 때마다이 노래가 찾아와세상이 둥근 것처럼 우린 동글동글인생은 회전목마우린...
# 3  달이 익어가니 서둘러 젊은 피야민들레 한 송이 들고사랑이 어지러이 떠다니는 밤이야날...
# 7  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 8  끝없이 별빛이 내리던 밤기분 좋은 바람이두 빰을 스치고새벽 바다 한곳을 보는아름다운...

# %%
#조건식을 만족하는 행과 모든열을 선택
condition = song_df['가수'] == '방탄소년단'
song_df.loc[condition, :]
# Out:
#                                            곡명     가수  \
# 16                        Permission to Dance  방탄소년단
# 18                                     Butter  방탄소년단
# 24                                   Dynamite  방탄소년단
# 53  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  방탄소년단
# 55                                         봄날  방탄소년단
# 66                               Life Goes On  방탄소년단
#
#                               앨범         발매일    장르     좋아요  \
# 16  Butter / Permission to Dance  2021.07.09    댄스  187576
# 18                        Butter  2021.05.21    댄스  256230
# 24    Dynamite (DayTime Version)  2020.08.24    댄스  426644
# 53     MAP OF THE SOUL : PERSONA  2019.04.12    댄스  430655
# 55          YOU NEVER WALK ALONE  2017.02.13  랩/힙합  552098
# 66                            BE  2020.11.20  랩/힙합  230328
#
#                                                    가사
# 16  It’s the thought of being youngWhen your heart...
# 18  Smooth like butterLike a criminal undercoverGo...
# 24  Cos ah ahI’m in the stars tonightSo watch me b...
# 53  모든 게 궁금해How’s your dayOh tell me뭐가 널 행복하게 하는지O...
# 55  보고 싶다이렇게 말하니까 더 보고 싶다너희 사진을 보고 있어도보고 싶다너무 야속한 ...
# 66  어느 날 세상이 멈췄어아무런 예고도 하나 없이봄은 기다림을 몰라서눈치 없이 와버렸어...

# %%
#모든행과 특정열을 1개 선택
#song_df['가수']
song_df.loc[:,'가수'].head()
# Out:
# 0               sokodomo
# 1    아넌딜라이트(Anandelight)
# 2                     개코
# 3                    아이유
# 4                    임영웅
# Name: 가수, dtype: object

# %%
#모든행과 특정열을 여러개 선택
song_df.loc[:,['가수','곡명','장르']].head()
# Out:
#                     가수                                      곡명          장르
# 0             sokodomo  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)        랩/힙합
# 1  아넌딜라이트(Anandelight)            쉬어 (Feat. MINO) (Prod. GRAY)        랩/힙합
# 2                   개코                  Wake Up (Prod. 코드 쿤스트)        랩/힙합
# 3                  아이유                         strawberry moon        록/메탈
# 4                  임영웅                               사랑은 늘 도망가  발라드, 국내드라마

# %%
#장르가 댄스인 가수,곡명,장르,발매일을 선택하세요
song_df.loc[song_df['장르'] == '댄스',['가수','곡명','장르','발매일']]\
.reset_index(drop=True)
# Out:
#                    가수                                         곡명  장르  \
# 0               aespa                                     Savage  댄스
# 1               aespa                                 Next Level  댄스
# 2               방탄소년단                        Permission to Dance  댄스
# 3               방탄소년단                                     Butter  댄스
# 4        태연 (TAEYEON)                                    Weekend  댄스
# 5               방탄소년단                                   Dynamite  댄스
# 6                 아이유                                        라일락  댄스
# 7                 아이유                                  Celebrity  댄스
# 8                 세븐틴                              Rock with you  댄스
# 9                 전소미                                  DUMB DUMB  댄스
# 10  Red Velvet (레드벨벳)                                   Queendom  댄스
# 11             브레이브걸스                               롤린 (Rollin')  댄스
# 12  오마이걸 (OH MY GIRL)                              Dun Dun Dance  댄스
# 13              방탄소년단  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  댄스
# 14        STAYC(스테이씨)                                       ASAP  댄스
# 15          BLACKPINK                             Lovesick Girls  댄스
# 16       TWICE (트와이스)                                  SCIENTIST  댄스
# 17        STAYC(스테이씨)                           색안경 (STEREOTYPE)  댄스
# 18          ITZY (있지)                                       LOCO  댄스
# 19                아이유                                어푸 (Ah puh)  댄스
# 20             브레이브걸스                             운전만해 (We Ride)  댄스
#
#            발매일
# 0   2021.10.05
# 1   2021.05.17
# 2   2021.07.09
# 3   2021.05.21
# 4   2021.07.06
# 5   2020.08.24
# 6   2021.03.25
# 7   2021.03.25
# 8   2021.10.22
# 9   2021.08.02
# 10  2021.08.16
# 11  2017.03.07
# 12  2021.05.10
# 13  2019.04.12
# 14  2021.04.08
# 15  2020.10.02
# 16  2021.11.12
# 17  2021.09.06
# 18  2021.09.24
# 19  2021.03.25
# 20  2020.08.14

# %%
#최근 발매일순으로 정렬
song_df.loc[song_df['장르'] == '댄스',['가수','곡명','장르','발매일']]\
.sort_values(by='발매일',ascending=False).reset_index(drop=True)
# Out:
#                    가수                                         곡명  장르  \
# 0        TWICE (트와이스)                                  SCIENTIST  댄스
# 1                 세븐틴                              Rock with you  댄스
# 2               aespa                                     Savage  댄스
# 3           ITZY (있지)                                       LOCO  댄스
# 4         STAYC(스테이씨)                           색안경 (STEREOTYPE)  댄스
# 5   Red Velvet (레드벨벳)                                   Queendom  댄스
# 6                 전소미                                  DUMB DUMB  댄스
# 7               방탄소년단                        Permission to Dance  댄스
# 8        태연 (TAEYEON)                                    Weekend  댄스
# 9               방탄소년단                                     Butter  댄스
# 10              aespa                                 Next Level  댄스
# 11  오마이걸 (OH MY GIRL)                              Dun Dun Dance  댄스
# 12        STAYC(스테이씨)                                       ASAP  댄스
# 13                아이유                                        라일락  댄스
# 14                아이유                                  Celebrity  댄스
# 15                아이유                                어푸 (Ah puh)  댄스
# 16          BLACKPINK                             Lovesick Girls  댄스
# 17              방탄소년단                                   Dynamite  댄스
# 18             브레이브걸스                             운전만해 (We Ride)  댄스
# 19              방탄소년단  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  댄스
# 20             브레이브걸스                               롤린 (Rollin')  댄스
#
#            발매일
# 0   2021.11.12
# 1   2021.10.22
# 2   2021.10.05
# 3   2021.09.24
# 4   2021.09.06
# 5   2021.08.16
# 6   2021.08.02
# 7   2021.07.09
# 8   2021.07.06
# 9   2021.05.21
# 10  2021.05.17
# 11  2021.05.10
# 12  2021.04.08
# 13  2021.03.25
# 14  2021.03.25
# 15  2021.03.25
# 16  2020.10.02
# 17  2020.08.24
# 18  2020.08.14
# 19  2019.04.12
# 20  2017.03.07

# %%
#모든행과 Slicing을 사용하여 가수 부터 발매일까지
song_df.loc[:,'가수':'발매일'].head()
# Out:
#                     가수                  앨범         발매일
# 0             sokodomo  쇼미더머니 10 Episode 2  2021.11.13
# 1  아넌딜라이트(Anandelight)  쇼미더머니 10 Episode 1  2021.11.06
# 2                   개코  쇼미더머니 10 Episode 1  2021.11.06
# 3                  아이유     strawberry moon  2021.10.19
# 4                  임영웅  신사와 아가씨 OST Part.2  2021.10.11

# %%
### iloc[] 사용
#행의 인덱스가 0부터 5까지, 열의 인덱스가 0:4
song_df.iloc[0:5, 0:4]
# Out:
#                                        곡명                   가수  \
# 0  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)             sokodomo
# 1            쉬어 (Feat. MINO) (Prod. GRAY)  아넌딜라이트(Anandelight)
# 2                  Wake Up (Prod. 코드 쿤스트)                   개코
# 3                         strawberry moon                  아이유
# 4                               사랑은 늘 도망가                  임영웅
#
#                    앨범         발매일
# 0  쇼미더머니 10 Episode 2  2021.11.13
# 1  쇼미더머니 10 Episode 1  2021.11.06
# 2  쇼미더머니 10 Episode 1  2021.11.06
# 3     strawberry moon  2021.10.19
# 4  신사와 아가씨 OST Part.2  2021.10.11

# %%
song_df.columns
# Out:
# Index(['곡명', '가수', '앨범', '발매일', '장르', '좋아요', '가사'], dtype='object')

# %%
like_max_value = song_df['좋아요'].max()
print(like_max_value)
# Out:
# 552098

# %%
song_df.loc[song_df['좋아요'] == like_max_value]
# Out:
#     곡명     가수                    앨범         발매일    장르     좋아요  \
# 55  봄날  방탄소년단  YOU NEVER WALK ALONE  2017.02.13  랩/힙합  552098
#
#                                                    가사
# 55  보고 싶다이렇게 말하니까 더 보고 싶다너희 사진을 보고 있어도보고 싶다너무 야속한 ...

# %%
like_min_value = song_df['좋아요'].min()
song_df.loc[song_df['좋아요'] == like_min_value]
# Out:
#          곡명   가수                        앨범         발매일          장르   좋아요  \
# 97  손을 잡아줘요  이하이  지금, 헤어지는 중입니다 OST Part.2  2021.11.14  발라드, 국내드라마  5115
#
#                                                    가사
# 97  내 맘을 깊이 들여다보면작은 구멍이 하나 있어요아무도 모르게 나조차도 모르게자라나고...

# %% [markdown]
# ### 100곡의 Song 정보가 포함된 데이터프레임 객체를 DB에 저장
# * pymysql 과 sqlalchemy 를 사용한다.

# %%
# !pip show sqlalchemy
# Out:
# Name: SQLAlchemy
# Version: 1.4.7
# Summary: Database Abstraction Library
# Home-page: http://www.sqlalchemy.org
# Author: Mike Bayer
# Author-email: mike_mp@zzzcomputing.com
# License: MIT
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires: greenlet
# Required-by:

# %%
# !pip show pymysql
# Out:
# Name: PyMySQL
# Version: 1.0.2
# Summary: Pure Python MySQL Driver
# Home-page: https://github.com/PyMySQL/PyMySQL/
# Author: yutaka.matsubara
# Author-email: yutaka.matsubara@gmail.com
# License: "MIT"
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
print(con)

#DataFrame의 to_sql() 함수로 dataframe 객체를 Table로 저정
#to_sql() name속성 테이블이름, if_exists속성 replace는 기존에 데이터가 있다면 overwrite 해라
song_df.to_sql(name='songs', con=engine, if_exists='replace', index=False)

con.close()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x0000020B088592B0>

# %%
#기존 DataFrame 객체의 복사본을 생성함
table_df = song_df.copy()
table_df.head()
# Out:
#                     곡명             가수                            앨범  \
# 0                 STAY  The Kid LAROI                          Stay
# 1                  신호등            이무진                           신호등
# 2          My Universe       Coldplay                   My Universe
# 3       OHAYO MY NIGHT    디핵 (D-Hack)                OHAYO MY NIGHT
# 4  Permission to Dance          방탄소년단  Butter / Permission to Dance
#
#           발매일    장르     좋아요                                                 가사
# 0  2021.07.09   POP  155719  I do the same thing I told youthat I never wou...
# 1  2021.05.14  록/메탈  216878  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 2  2021.09.24   POP   82762  You, you are my universe andI just want to put...
# 3  2020.06.20  랩/힙합  135318  너를 사랑하고 있어너를 사랑하고 있어자기야 날 사랑해주면 안 될까말처럼 쉽지는 않은...
# 4  2021.07.09    댄스  177415  It’s the thought of being youngWhen your heart...

# %%
table_df.columns = ['title','singer','album','release_date','genre','likes','lyric']
table_df.head(2)
# Out:
#   title         singer album release_date genre   likes  \
# 1  STAY  The Kid LAROI  Stay   2021.07.09   POP  155719
# 2   신호등            이무진   신호등   2021.05.14  록/메탈  216878
#
#                                                lyric
# 1  I do the same thing I told youthat I never wou...
# 2  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...

# %%
#index가 1부터 시작되도록 변경

import numpy as np

table_df.index = np.arange(1,len(table_df)+1)
table_df.head(2)
# Out:
#   title         singer album release_date genre   likes  \
# 1  STAY  The Kid LAROI  Stay   2021.07.09   POP  155719
# 2   신호등            이무진   신호등   2021.05.14  록/메탈  216878
#
#                                                lyric
# 1  I do the same thing I told youthat I never wou...
# 2  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...

# %% [markdown]
# ### 컬럼명과 DataType을 변경해서 Table로 저장하기

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
print(con)

#['곡명', '가수', '앨범', '발매일', '장르', '가사']
#DataFrame의 to_sql() 함수로 dataframe 객체를 Table로 저정
table_df.to_sql(name='songs100', con=engine, if_exists='replace', index=True,\
              index_label='id',
              dtype={
                  'id':sqlalchemy.types.INTEGER(),
                  'title':sqlalchemy.types.VARCHAR(200),
                  'singer':sqlalchemy.types.VARCHAR(100),
                  'album':sqlalchemy.types.VARCHAR(100),
                  'release_date':sqlalchemy.DATE,
                  'genre':sqlalchemy.types.VARCHAR(100),
                  'likes':sqlalchemy.types.BigInteger,
                  'lyric':sqlalchemy.types.VARCHAR(2500)
              })
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x0000020B087D3610>

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')

from sqlalchemy.sql import text
with engine.connect() as con:

    data = ( { "title": "노래", "singer": "둘리","album":"둘리앨범","release_date":"2021-07-09",
              "genre":"동요","likes":1000,"lyric":"aa" }, )
    
    stmt = text("""alter table songs100 modify id int auto_increment;""")
    
    statement = text("""INSERT INTO songs100 (title,singer,album,release_date,genre,likes,lyric) 
    VALUES (:title, :singer, :album, :release_date, :genre, :likes, :lyric)""")

    for line in data:
        con.execute(stmt)
        con.execute(statement, **line)

# %% [markdown]
# ### Table을 DataFrame 객체로 변환하기

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
# Table을 DataFrame으로 가져오기
songs100_df=pd.read_sql_table('songs100',con)

#DB 연결 종료
con.close()

songs100_df.head()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#    id                title         singer                         album  \
# 0   1                 STAY  The Kid LAROI                          Stay
# 1   2                  신호등            이무진                           신호등
# 2   3          My Universe       Coldplay                   My Universe
# 3   4       OHAYO MY NIGHT    디핵 (D-Hack)                OHAYO MY NIGHT
# 4   5  Permission to Dance          방탄소년단  Butter / Permission to Dance
#
#   release_date genre    like  \
# 0   2021-07-09   POP  155719
# 1   2021-05-14  록/메탈  216878
# 2   2021-09-24   POP   82762
# 3   2020-06-20  랩/힙합  135318
# 4   2021-07-09    댄스  177415
#
#                                                lyric
# 0  I do the same thing I told youthat I never wou...
# 1  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 2  You, you are my universe andI just want to put...
# 3  너를 사랑하고 있어너를 사랑하고 있어자기야 날 사랑해주면 안 될까말처럼 쉽지는 않은...
# 4  It’s the thought of being youngWhen your heart...

# %%
def search_album(keyword):
    sql = """select * from songs100 where album like %s;"""

    import pymysql
    import sqlalchemy

    #pymysql과 sqlalchemy 를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                          encoding='utf-8')
    print(engine)
    #Engine을 사용해서 DB에 연결 
    con = engine.connect()
    
    #query실행한 결과를 DataFrame 객체로 변환하기
    album_df = pd.read_sql_query(sql, con=con, params=('%' + keyword + '%',))
    print(len(album_df))
    con.close()
    return album_df

# %%
result = search_album('OST')
result
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# 10
#    id                                  title   singer  \
# 0  11                                   좋아좋아      조정석
# 1  20                                  비와 당신      이무진
# 2  33                             가을 우체국 앞에서      김대명
# 3  40                                내 손을 잡아      아이유
# 4  63                                    아로하      조정석
# 5  69  모든 날, 모든 순간 (Every day, Every Moment)       폴킴
# 6  72               흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야      장범준
# 7  81                              여전히 아름다운지      세븐틴
# 8  83                 이젠 잊기로 해요 (Drama Ver.)  미도와 파라솔
# 9  96                              Butterfly      전미도
#
#                        album release_date        genre    like  \
# 0   슬기로운 의사생활 시즌2 OST Part 5   2021-07-16   발라드, 국내드라마   71552
# 1   슬기로운 의사생활 시즌2 OST Part 1   2021-06-18  록/메탈, 국내드라마   87050
# 2   슬기로운 의사생활 시즌2 OST Part 2   2021-06-25   발라드, 국내드라마   45841
# 3          최고의 사랑 OST Part.4   2011-05-25   발라드, 국내드라마  169333
# 4       슬기로운 의사생활 OST Part 3   2020-03-27   발라드, 국내드라마  228435
# 5    '키스 먼저 할까요?' OST Part.3   2018-03-20   발라드, 국내드라마  376320
# 6          멜로가 체질 OST Part 3   2019-08-23  록/메탈, 국내드라마  293672
# 7   슬기로운 의사생활 시즌2 OST Part 8   2021-08-13   발라드, 국내드라마   44304
# 8  슬기로운 의사생활 시즌2 OST Special   2021-07-30  록/메탈, 국내드라마   27574
# 9  슬기로운 의사생활 시즌2 OST Part 12   2021-09-17  록/메탈, 국내드라마   18154
#
#                                                lyric
# 0  처음 널 만나는 날노란 세 송이 장미를 들고룰루랄라 신촌을 향하는내 가슴은 마냥 두...
# 1  이젠 당신이 그립지 않죠보고 싶은 마음도 없죠사랑한 것도 잊혀 가네요조용하게알 수 ...
# 2  가을 우체국 앞에서그대를 기다리다노오란 은행잎들이바람에 날려가고지나는 사람들 같이저...
# 3  느낌이 오잖아 떨리고 있잖아언제까지 눈치만 볼 거니네 맘을 말해봐 딴청 피우지 말란...
# 4  어두운 불빛아래 촛불 하나와인 잔에 담긴 약속하나항상 너의 곁에서 널 지켜줄거야날 ...
# 5  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 6  흔들리는 꽃들 속에서네 샴푸향이 느껴진거야스쳐지나간건가 뒤돌아보지만그냥 사람들만 보...
# 7  첨엔 혼자라는 게 편했지자유로운 선택과 시간에너의 기억을 지운 듯 했어정말 난 그런...
# 8  이젠 잊기로 해요이젠 잊어야 해요사람 없는 성당에서 무릎 꿇고기도했던걸 잊어요이젠 ...
# 9  어리석은 세상은 너를 몰라누에 속에 감춰진 너를 못 봐나는 알아 내겐 보여그토록 찬...

# %%
def search_song(singer,title):
    sql = """select * from songs100 where singer like %s or title like %s;"""
    
    import pymysql
    import sqlalchemy

    #pymysql과 sqlalchemy 를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                          encoding='utf-8')
    print(engine)
    #Engine을 사용해서 DB에 연결 
    con = engine.connect()
    
    singer = f'%{singer}%'
    title = f'%{title}%'
    
    result = pd.read_sql_query(sql,con=con, params=(singer,title))
    
    con.close()
    
    return result

# %%
result_df = search_song('김','a')
result_df
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#     id                                              title             singer  \
# 0    1                                               STAY      The Kid LAROI
# 1    4                                     OHAYO MY NIGHT        디핵 (D-Hack)
# 2    5                                Permission to Dance              방탄소년단
# 3   12             Peaches (Feat. Daniel Caesar & Giveon)      Justin Bieber
# 4   15                                         Bad Habits         Ed Sheeran
# 5   16                                           Dynamite              방탄소년단
# 6   26                                      Dun Dun Dance  오마이걸 (OH MY GIRL)
# 7   29                                               ASAP        STAYC(스테이씨)
# 8   31       Savage Love (Laxed - Siren Beat) (BTS Remix)          Jawsh 685
# 9   32      사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)                호미들
# 10  33                                         가을 우체국 앞에서                김대명
# 11  37          작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)              방탄소년단
# 12  44                   찰나가 영원이 될 때 (The Eternal Moment)       마크툽 (MAKTUB)
# 13  47                              치맛바람 (Chi Mat Ba Ram)             브레이브걸스
# 14  49                                        Off My Face      Justin Bieber
# 15  50                                       Alcohol-Free       TWICE (트와이스)
# 16  60                                 빨간 립스틱 (Feat. 윤미래)                이하이
# 17  62  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...       David Guetta
# 18  68                                           Lemonade            NCT 127
# 19  69              모든 날, 모든 순간 (Every day, Every Moment)                 폴킴
# 20  70                      비 오는 날 듣기 좋은 노래 (Feat. Colde)   에픽하이 (EPIK HIGH)
# 21  73           오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)       마크툽 (MAKTUB)
# 22  74                        에잇(Prod.&Feat. SUGA of BTS)                아이유
# 23  77                                        어푸 (Ah puh)                아이유
# 24  79              LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)                양요섭
# 25  83                             이젠 잊기로 해요 (Drama Ver.)            미도와 파라솔
# 26  94                                          Road Trip            NCT 127
# 27  98                                   사실 나는 (Feat.전건호)               경서예지
# 28  99                          내일의 나에게 (The Rainy Night)            NCT 127
#
#                                            album release_date           genre  \
# 0                                           Stay   2021-07-09             POP
# 1                                 OHAYO MY NIGHT   2020-06-20            랩/힙합
# 2                   Butter / Permission to Dance   2021-07-09              댄스
# 3                                        Justice   2021-03-19             POP
# 4                                        Shivers   2021-08-19             POP
# 5                     Dynamite (DayTime Version)   2020-08-24              댄스
# 6                                  Dear OHMYGIRL   2021-05-10              댄스
# 7                                        STAYDOM   2021-04-08              댄스
# 8   Savage Love (Laxed - Siren Beat) [BTS Remix]   2020-10-02             POP
# 9                                      사이렌 Remix   2021-03-20            랩/힙합
# 10                      슬기로운 의사생활 시즌2 OST Part 2   2021-06-25      발라드, 국내드라마
# 11                     MAP OF THE SOUL : PERSONA   2019-04-12              댄스
# 12                   Red Moon : Beyond The Light   2021-09-19  R&B/Soul, 인디음악
# 13                                  Summer Queen   2021-06-17              댄스
# 14                                       Justice   2021-03-19             POP
# 15                                 Taste of Love   2021-06-09              댄스
# 16                                        4 ONLY   2021-09-09        R&B/Soul
# 17                                        Listen   2014-11-25          일렉트로니카
# 18                       Sticker - The 3rd Album   2021-09-17            랩/힙합
# 19                       '키스 먼저 할까요?' OST Part.3   2018-03-20      발라드, 국내드라마
# 20                               비 오는 날 듣기 좋은 노래   2021-06-29            랩/힙합
# 21                    Red Moon : To You My Light   2019-06-09  R&B/Soul, 인디음악
# 22                                            에잇   2020-05-06            록/메탈
# 23                          IU 5th Album 'LILAC'   2021-03-25              댄스
# 24         LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)   2021-03-05              댄스
# 25                     슬기로운 의사생활 시즌2 OST Special   2021-07-30     록/메탈, 국내드라마
# 26                       Sticker - The 3rd Album   2021-09-17        R&B/Soul
# 27                                         사실 나는   2020-04-12             발라드
# 28                       Sticker - The 3rd Album   2021-09-17             발라드
#
#       like                                              lyric
# 0   155719  I do the same thing I told youthat I never wou...
# 1   135318  너를 사랑하고 있어너를 사랑하고 있어자기야 날 사랑해주면 안 될까말처럼 쉽지는 않은...
# 2   177415  It’s the thought of being youngWhen your heart...
# 3   200246  I got my peaches out in GeorgiaOh yeah shitI g...
# 4    72861  Every time you come aroundyou know I can’t say...
# 5   424022  Cos ah ahI’m in the stars tonightSo watch me b...
# 6   143217  Dun Dun Dance Dun Dun DanceDun Dun DanceJust d...
# 7   127785  STAYC girls it’s going downTime is running boy...
# 8   186877  Savage loveDid somebody did somebodyBreak your...
# 9   112421  울려댔어 사이렌텅 빈 길거리엔도망치다 흘린 칼자루와 피가 흥건해우리 그때 어릴땐뭘 ...
# 10   45841  가을 우체국 앞에서그대를 기다리다노오란 은행잎들이바람에 날려가고지나는 사람들 같이저...
# 11  429187  모든 게 궁금해How’s your dayOh tell me뭐가 널 행복하게 하는지O...
# 12   15075  서로를 향한 마음이우주의 작은 뭉쳐짐이라면이 아름다운 기억이 흩어져도사라지진 않을 ...
# 13   92997  You know what it isB. girls are back, Brave So...
# 14   78442  One touch and you got me stonedHigher than I'v...
# 15   75903  너와 있을 땐 내게신기한 변화가 있는데자꾸 미소 짓게 돼아무 일도 없는데자꾸 마법에...
# 16   18461  오늘 밤은 이 분위기에 취해아무런 생각 없이 groove it고민하지 마 just ...
# 17   40549
# 18   46382  Lemonade Lemonade제대로 건드렸어 you또 뒤로 숨어서 넌 typing...
# 19  376320  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 20   62104  비가 오고네가 생각나비가 오고또 비가 오고슬픈 음악이 흐르면옛 노래처럼네가 생각나네...
# 21  246368  별빛이 내린 밤그 풍경 속 너와 나날 새롭게 하는따뜻하게 만드는니 눈빛 니 미소영원...
# 22  367467  So are you happy nowFinally happy now are you뭐...
# 23  102558  I’m such a good surfer가라앉지 않기비틀 비 비틀 거리다가 풍덩 u...
# 24  102604  참 많이 궁금해전부 다 궁금해왜 잠이 안 오고 네 얼굴만 보여나도 궁금해이 맘이 궁...
# 25   27574  이젠 잊기로 해요이젠 잊어야 해요사람 없는 성당에서 무릎 꿇고기도했던걸 잊어요이젠 ...
# 26   39906  떠나 Road Trip우리만이 아는 곳으로어디든지 가고 싶어손을 꼭 잡고 yeahT...
# 27   83692  그땐 우리 둘 다 철없이어리기만 했나 봐태어나 처음 설레는너를 만나서 세상에 부러울...
# 28   35627  Yeah yeah listen너와 듣던 이 음악을되감아봐 이 밤에또 흩어지지 못한 ...
