# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"], 
                   columns=["A", "B", "C", "D"])
                   #columns=pd.Index(["A", "B", "C", "D"], name="Genus"))

# %%
#fig = plt.figure()
df2.plot(kind="barh", stacked=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = [11,21,25,27,33,34,36,41,43,45,50,53,58,61,72,74,85,87,82,91,95,93,96,100]
#print(x)
plt.figure()
obj = pd.Series(x)
#obj.hist(bins=20)

#n, bins, patches = plt.hist(obj, bins=10,facecolor='blue', alpha=0.5)
n, bins, patches = plt.hist(obj, bins=10,facecolor='blue', alpha=0.5,normed=True)
plt.grid()
#plt.ylim([1, 5])
plt.xlim([10,100])

# print(n)
# print(bins)
# for p in patches:
#     print(patches)
#n, bins, patches = plt.hist(obj, bins=10,normed=True)
#plt.hist(x, bins=6, facecolor='blue', alpha=0.5)
# Out:
# (10, 100)

# %%
n
# Out:
# array([ 3.,  3.,  2.,  3.,  3.,  1.,  2.,  1.,  2.,  3.])

# %%
bins
# Out:
# array([  21. ,   28.9,   36.8,   44.7,   52.6,   60.5,   68.4,   76.3,
#          84.2,   92.1,  100. ])

# %%
#히스토그램
s3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
s3
# Out:
# 0      0.649673
# 1     -0.256160
# 2     -0.451663
# 3     -0.015455
# 4     -0.570523
# 5      0.013706
# 6      0.123704
# 7     -1.768128
# 8     -1.472807
# 9     -1.929439
# 10     0.723061
# 11     1.892118
# 12    -0.196892
# 13     0.014538
# 14    -0.848359
# 15    -1.139331
# 16    -0.715336
# 17     0.902709
# 18     0.305788
# 19    -1.688823
# 20     0.929760
# 21    -0.879869
# 22     0.210871
# 23    -1.022898
# 24     1.083877
# 25    -0.479489
# 26    -0.367146
# 27     0.967627
# 28     0.052041
# 29     0.755346
#          ...
# 170   -0.133168
# 171    0.051163
# 172    1.250433
# 173    1.081939
# 174    1.265557
# 175    0.723000
# 176    1.131429
# 177    0.357729
# 178    0.992343
# 179    0.406787
# 180    0.138197
# 181   -0.009876
# 182    1.409940
# 183    0.557652
# 184    1.242398
# 185   -0.180618
# 186    0.755393
# 187   -0.380628
# 188    0.263988
# 189    0.544848
# 190   -0.710531
# 191    1.017659
# 192    0.595523
# 193   -0.698133
# ...

# %%
s3.min()
# Out:
# -2.1575791189858604

# %%
s3.max()
# Out:
# 3.1519850937893135

# %%
s3.median()
# Out:
# -0.01658033561957036

# %%
fig = plt.figure()
s3.hist()

# %%
fig = plt.figure()
plt.hist(s3)
plt.grid()

# %%
fig = plt.figure()
s3.hist(bins=50)

# %%
plt.figure()
s3.hist(bins=50, normed=True)

# %%
#DataFrame으로 histotgram 그리기
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
plt.figure(facecolor="r")
#alpha 는 투명도
#bins 는 구간
df4.plot.hist(bins=20,alpha=0.5)

# plt.hist(df4["a"],bins=20)
# plt.hist(df4["b"],bins=20)
# plt.hist(df4["c"],bins=20)
# plt.grid()

# plt.hist(df4["a"], bins=20,alpha=0.5,label='a')
# plt.hist(df4["b"], bins=20,alpha=0.5,label='b')
# plt.hist(df4["c"], bins=20,alpha=0.5,label='c')
# plt.grid()

# # Set the x and y boundaries of the figure
#plt.ylim([0, 160])
#plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
 
 
# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)
 
num_bins = 20
plt.figure()
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor='blue', alpha=0.5)
 
# add a 'best fit' line
y = mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')
 
# # Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %%
x1 = np.random.normal(1, 1, size=(100, 1)) 
x2 = np.random.normal(-2, 4, size=(100, 1)) 
X = np.concatenate((x1, x2), axis=1)

# %%
X.shape
# Out:
# (100, 2)

# %%
df3 = pd.DataFrame(X, columns=["x1", "x2"])

# %%
fig = plt.figure()
plt.scatter(df3["x1"], df3["x2"])

# %%
df = pd.DataFrame(np.random.randn(50,2),columns=["a","b"])
fig = plt.figure()
df.plot.scatter(x="a",y="b")

# %%
fig = plt.figure()
plt.scatter(df["a"],df["b"])

# %%
# Create data
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
colors = (0,0,0)
area = np.pi*3
 
# scatter Plot
plt.figure()
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))
 
data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water") 
 
# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")
 
for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
 
plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()
